# %%
   Image(url='https://m.atcdn.co.uk/retailer/media/%7Bresize%7D/8a428cac77afe9d70177b997fcb016a2.jpg', width=1000)
# Out:
# <img src="https://m.atcdn.co.uk/retailer/media/%7Bresize%7D/8a428cac77afe9d70177b997fcb016a2.jpg" width="1000"/>

# %% [markdown]
# ## 🔹 Importing required libraries

# %%
from IPython.display import Image

import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 🔹 Load the dataset using the pandas read function

# %%
data = pd.read_csv(r'C:\Users\ZMZM\Desktop\Dataset\used_cars_UK.csv')
data
# Out:
#       Unnamed: 0           title  Price  Mileage(miles)  Registration_Year  \
# 0              0     SKODA Fabia   6900           70189               2016
# 1              1  Vauxhall Corsa   1495           88585               2008
# 2              2     Hyundai i30    949          137000               2011
# 3              3      MINI Hatch   2395           96731               2010
# 4              4  Vauxhall Corsa   1000           85000               2013
# ...          ...             ...    ...             ...                ...
# 3680        4723  Renault Megane   1395           76202               2006
# 3681        4724         Audi A4   6990          119000               2012
# 3682        4725    BMW 3 Series   3995          139000               2013
# 3683        4726    Honda Accord   1390          179190               2007
# 3684        4727  Vauxhall Corsa   2000           82160               2013
#
# ...

# %%
car = data.copy()

# %% [markdown]
# ## 🔹 Set the dataset information

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3685 entries, 0 to 3684
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         3685 non-null   int64
#  1   title              3685 non-null   object
#  2   Price              3685 non-null   int64
#  3   Mileage(miles)     3685 non-null   int64
#  4   Registration_Year  3685 non-null   int64
#  5   Previous Owners    2276 non-null   float64
#  6   Fuel type          3685 non-null   object
#  7   Body type          3685 non-null   object
#  8   Engine             3640 non-null   object
#  9   Gearbox            3685 non-null   object
#  10  Doors              3660 non-null   float64
#  11  Seats              3650 non-null   float64
#  12  Emission Class     3598 non-null   object
#  13  Service history    540 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 403.2+ KB

# %% [markdown]
# ### 🔹 Data Preparation & Exploration

# %%
car.isnull().sum()
# Out:
# Unnamed: 0              0
# title                   0
# Price                   0
# Mileage(miles)          0
# Registration_Year       0
# Previous Owners      1409
# Fuel type               0
# Body type               0
# Engine                 45
# Gearbox                 0
# Doors                  25
# Seats                  35
# Emission Class         87
# Service history      3145
# dtype: int64

# %%
car.rename(columns={'Unnamed: 0': 'id'}, inplace = True)
car
# Out:
#         id           title  Price  Mileage(miles)  Registration_Year  \
# 0        0     SKODA Fabia   6900           70189               2016
# 1        1  Vauxhall Corsa   1495           88585               2008
# 2        2     Hyundai i30    949          137000               2011
# 3        3      MINI Hatch   2395           96731               2010
# 4        4  Vauxhall Corsa   1000           85000               2013
# ...    ...             ...    ...             ...                ...
# 3680  4723  Renault Megane   1395           76202               2006
# 3681  4724         Audi A4   6990          119000               2012
# 3682  4725    BMW 3 Series   3995          139000               2013
# 3683  4726    Honda Accord   1390          179190               2007
# 3684  4727  Vauxhall Corsa   2000           82160               2013
#
#       Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# ...

# %%
car['Service history'].value_counts()
# Out:
# Service history
# Full    540
# Name: count, dtype: int64

# %%
car['Service history'] = car['Service history'].replace('Full', '1')

# %%
car.head()
# Out:
#    id           title  Price  Mileage(miles)  Registration_Year  \
# 0   0     SKODA Fabia   6900           70189               2016
# 1   1  Vauxhall Corsa   1495           88585               2008
# 2   2     Hyundai i30    949          137000               2011
# 3   3      MINI Hatch   2395           96731               2010
# 4   4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              NaN    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              NaN    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class Service history
# 0         Euro 6             NaN
# 1         Euro 4               1
# 2         Euro 5             NaN
# ...

# %%
car['Service history'] = pd.to_numeric(car['Service history'])
car
# Out:
#         id           title  Price  Mileage(miles)  Registration_Year  \
# 0        0     SKODA Fabia   6900           70189               2016
# 1        1  Vauxhall Corsa   1495           88585               2008
# 2        2     Hyundai i30    949          137000               2011
# 3        3      MINI Hatch   2395           96731               2010
# 4        4  Vauxhall Corsa   1000           85000               2013
# ...    ...             ...    ...             ...                ...
# 3680  4723  Renault Megane   1395           76202               2006
# 3681  4724         Audi A4   6990          119000               2012
# 3682  4725    BMW 3 Series   3995          139000               2013
# 3683  4726    Honda Accord   1390          179190               2007
# 3684  4727  Vauxhall Corsa   2000           82160               2013
#
#       Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3685 entries, 0 to 3684
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3685 non-null   int64
#  1   title              3685 non-null   object
#  2   Price              3685 non-null   int64
#  3   Mileage(miles)     3685 non-null   int64
#  4   Registration_Year  3685 non-null   int64
#  5   Previous Owners    2276 non-null   float64
#  6   Fuel type          3685 non-null   object
#  7   Body type          3685 non-null   object
#  8   Engine             3640 non-null   object
#  9   Gearbox            3685 non-null   object
#  10  Doors              3660 non-null   float64
#  11  Seats              3650 non-null   float64
#  12  Emission Class     3598 non-null   object
#  13  Service history    540 non-null    float64
# dtypes: float64(4), int64(4), object(6)
# memory usage: 403.2+ KB

# %%
car.isnull().sum()
# Out:
# id                      0
# title                   0
# Price                   0
# Mileage(miles)          0
# Registration_Year       0
# Previous Owners      1409
# Fuel type               0
# Body type               0
# Engine                 45
# Gearbox                 0
# Doors                  25
# Seats                  35
# Emission Class         87
# Service history      3145
# dtype: int64

# %%
car = car.fillna(0.0)

# %%
car
# Out:
#         id           title  Price  Mileage(miles)  Registration_Year  \
# 0        0     SKODA Fabia   6900           70189               2016
# 1        1  Vauxhall Corsa   1495           88585               2008
# 2        2     Hyundai i30    949          137000               2011
# 3        3      MINI Hatch   2395           96731               2010
# 4        4  Vauxhall Corsa   1000           85000               2013
# ...    ...             ...    ...             ...                ...
# 3680  4723  Renault Megane   1395           76202               2006
# 3681  4724         Audi A4   6990          119000               2012
# 3682  4725    BMW 3 Series   3995          139000               2013
# 3683  4726    Honda Accord   1390          179190               2007
# 3684  4727  Vauxhall Corsa   2000           82160               2013
#
#       Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# ...

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3685 entries, 0 to 3684
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3685 non-null   int64
#  1   title              3685 non-null   object
#  2   Price              3685 non-null   int64
#  3   Mileage(miles)     3685 non-null   int64
#  4   Registration_Year  3685 non-null   int64
#  5   Previous Owners    3685 non-null   float64
#  6   Fuel type          3685 non-null   object
#  7   Body type          3685 non-null   object
#  8   Engine             3685 non-null   object
#  9   Gearbox            3685 non-null   object
#  10  Doors              3685 non-null   float64
#  11  Seats              3685 non-null   float64
#  12  Emission Class     3685 non-null   object
#  13  Service history    3685 non-null   float64
# dtypes: float64(4), int64(4), object(6)
# memory usage: 403.2+ KB

# %%
car['Service history'] = car['Service history'].astype('int')

# %%
car.head()
# Out:
#    id           title  Price  Mileage(miles)  Registration_Year  \
# 0   0     SKODA Fabia   6900           70189               2016
# 1   1  Vauxhall Corsa   1495           88585               2008
# 2   2     Hyundai i30    949          137000               2011
# 3   3      MINI Hatch   2395           96731               2010
# 4   4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              0.0    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              0.0    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class  Service history
# 0         Euro 6                0
# 1         Euro 4                1
# 2         Euro 5                0
# ...

# %%
name = sns.countplot(x = 'Service history', data = car)
plt.grid(True)

# %%
car.describe()
# Out:
#                 id         Price  Mileage(miles)  Registration_Year  \
# count  3685.000000   3685.000000    3.685000e+03        3685.000000
# mean   2314.770963   5787.145726    8.132816e+04        2011.835007
# std    1415.821308   4480.810572    3.942083e+04           5.092566
# min       0.000000    400.000000    1.000000e+00        1953.000000
# 25%    1059.000000   2490.000000    5.698400e+04        2008.000000
# 50%    2279.000000   4000.000000    8.000000e+04        2012.000000
# 75%    3593.000000   7995.000000    1.030000e+05        2015.000000
# max    4727.000000  33900.000000    1.110100e+06        2023.000000
#
#        Previous Owners        Doors        Seats  Service history
# count      3685.000000  3685.000000  3685.000000      3685.000000
# mean          1.734057     4.291723     4.853731         0.146540
# std           1.827033     1.045568     0.745628         0.353695
# min           0.000000     0.000000     0.000000         0.000000
# ...

# %%
car.head()
# Out:
#    id           title  Price  Mileage(miles)  Registration_Year  \
# 0   0     SKODA Fabia   6900           70189               2016
# 1   1  Vauxhall Corsa   1495           88585               2008
# 2   2     Hyundai i30    949          137000               2011
# 3   3      MINI Hatch   2395           96731               2010
# 4   4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              0.0    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              0.0    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class  Service history
# 0         Euro 6                0
# 1         Euro 4                1
# 2         Euro 5                0
# ...

# %%
cars = car.groupby('Price').title.sum()
cars
# Out:
# Price
# 400                                  SEAT Ibiza
# 450                              Vauxhall Astra
# 495                              Vauxhall Astra
# 499                                 Ford Fiesta
# 500                    Renault ClioRenault Clio
#                           ...
# 25100             Land Rover Range Rover Evoque
# 25995    SEAT AtecaLand Rover Range Rover Sport
# 28240                             BMW X3 Series
# 30000              Land Rover Range Rover Sport
# 33900                   Mercedes-Benz GLE Class
# Name: title, Length: 866, dtype: object

# %%
car['Fuel type'].value_counts()
# Out:
# Fuel type
# Petrol                   2361
# Diesel                   1218
# Petrol Hybrid              47
# Electric                   31
# Petrol Plug-in Hybrid      27
# Diesel Hybrid               1
# Name: count, dtype: int64

# %%
plt.figure(figsize=((12,4)))
plt.hist(car['Fuel type'] , bins=6, color='lightskyblue', width = 0.6)
plt.grid(True)

plt.show()

# %%
car.head()
# Out:
#    id           title  Price  Mileage(miles)  Registration_Year  \
# 0   0     SKODA Fabia   6900           70189               2016
# 1   1  Vauxhall Corsa   1495           88585               2008
# 2   2     Hyundai i30    949          137000               2011
# 3   3      MINI Hatch   2395           96731               2010
# 4   4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              0.0    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              0.0    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class  Service history
# 0         Euro 6                0
# 1         Euro 4                1
# 2         Euro 5                0
# ...

# %%
car['Gearbox'].value_counts()
# Out:
# Gearbox
# Manual       2868
# Automatic     817
# Name: count, dtype: int64

# %%
name = sns.countplot(x = 'Gearbox', data = car)
plt.grid(True)

# %%
car.head(5)
# Out:
#    id           title  Price  Mileage(miles)  Registration_Year  \
# 0   0     SKODA Fabia   6900           70189               2016
# 1   1  Vauxhall Corsa   1495           88585               2008
# 2   2     Hyundai i30    949          137000               2011
# 3   3      MINI Hatch   2395           96731               2010
# 4   4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              0.0    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              0.0    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class  Service history
# 0         Euro 6                0
# 1         Euro 4                1
# 2         Euro 5                0
# ...

# %%
car['Registration_Year'].value_counts()
# Out:
# Registration_Year
# 2011    289
# 2014    287
# 2012    275
# 2010    271
# 2009    251
# 2007    246
# 2016    245
# 2013    242
# 2008    226
# 2019    211
# 2015    210
# 2017    164
# 2006    149
# 2020    106
# 2005    104
# 2018     95
# 2021     85
# 2004     72
# 2003     53
# 2002     30
# 2001     25
# 2022      8
# 2023      6
# 1999      5
# 2000      4
# 1997      3
# 1990      3
# 1995      3
# 1998      3
# 1988      2
# 1987      2
# 1991      2
# 1972      1
# 1992      1
# 1996      1
# 1985      1
# 1981      1
# 1993      1
# 1989      1
# 1953      1
# Name: count, dtype: int64

# %%
name = [name for name, df in car.groupby('Registration_Year')]
plt.figure(figsize=((14,3)))

plt.plot(name, car.groupby(['Registration_Year']).count(), marker = 'o', c = 'g')
plt.xticks(name)
plt.xticks(rotation='vertical', size=8)
plt.show()

# %%
car.head(5)
# Out:
#    id           title  Price  Mileage(miles)  Registration_Year  \
# 0   0     SKODA Fabia   6900           70189               2016
# 1   1  Vauxhall Corsa   1495           88585               2008
# 2   2     Hyundai i30    949          137000               2011
# 3   3      MINI Hatch   2395           96731               2010
# 4   4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              0.0    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              0.0    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class  Service history
# 0         Euro 6                0
# 1         Euro 4                1
# 2         Euro 5                0
# ...

# %%
car.groupby('Engine').get_group('6.3L')
# Out:
#         id                  title  Price  Mileage(miles)  Registration_Year  \
# 3047  3955  Mercedes-Benz M Class  10850          107500               2007
#
#       Previous Owners Fuel type Body type Engine    Gearbox  Doors  Seats  \
# 3047              5.0    Petrol       SUV   6.3L  Automatic    5.0    5.0
#
#      Emission Class  Service history
# 3047         Euro 4                0

# %%
car[car['title'].str.contains('Mercedes')]
# Out:
#         id                    title  Price  Mileage(miles)  Registration_Year  \
# 21      22       Mercedes-Benz A180  14498           53055               2019
# 25      26    Mercedes-Benz A Class  15900           62402               2019
# 38      40    Mercedes-Benz A Class  15900           62402               2019
# 78      84    Mercedes-Benz A Class  15900           62402               2019
# 82      88    Mercedes-Benz B Class   2650           85000               2008
# ...    ...                      ...    ...             ...                ...
# 3210  4160  Mercedes-Benz GLE Class  33900           92000               2019
# 3299  4271    Mercedes-Benz E Class   2994          135000               2011
# 3382  4369    Mercedes-Benz C Class   1495           72200               2001
# 3574  4598        Mercedes-Benz CLK   2000          139571               2009
# 3592  4623    Mercedes-Benz C Class   1250          170000               2007
#
# ...

# %%
car['Body type'].value_counts()
# Out:
# Body type
# Hatchback      2279
# SUV             460
# Saloon          368
# Estate          171
# MPV             153
# Coupe           139
# Convertible     109
# Pickup            3
# Combi Van         2
# Minibus           1
# Name: count, dtype: int64

# %%
plt.figure(figsize=((10,4)))
plt.hist(car['Body type'] , bins=10, color='lightskyblue', width = 0.8)
plt.grid(True)
plt.xticks(rotation='vertical', size=12)
plt.show()

# %%
car.groupby('Price').title.sum()
# Out:
# Price
# 400                                  SEAT Ibiza
# 450                              Vauxhall Astra
# 495                              Vauxhall Astra
# 499                                 Ford Fiesta
# 500                    Renault ClioRenault Clio
#                           ...
# 25100             Land Rover Range Rover Evoque
# 25995    SEAT AtecaLand Rover Range Rover Sport
# 28240                             BMW X3 Series
# 30000              Land Rover Range Rover Sport
# 33900                   Mercedes-Benz GLE Class
# Name: title, Length: 866, dtype: object

# %%
car.groupby('Registration_Year').title.sum()
# Out:
# Registration_Year
# 1953                                 Lagonda LG6 Roadster
# 1972                                            MG Midget
# 1981                                       Marcos Martina
# 1985                                         Nissan Sunny
# 1987                              Porsche 944BMW 3 Series
# 1988                       Volkswagen GolfVolkswagen Golf
# 1989                                            Volvo 740
# 1990                     Rover MiniToyota CamryCitroen BX
# 1991                       Mercedes-Benz 260Toyota Carina
# 1992                                             Saab 900
# 1993                                      Volkswagen Polo
# 1995                     Citroen XMProton ProtonRover 800
# 1996                                      Volkswagen Golf
# 1997                Lexus GS 300Peugeot 306Nissan Primera
# 1998                  Ford MondeoPeugeot 406Honda Prelude
# 1999    BMW 3 SeriesHonda Cr-vLand Rover FreelanderBMW...
# ...

# %%
car.groupby('Fuel type').title.sum()
# Out:
# Fuel type
# Diesel                   SKODA FabiaVauxhall CorsaPeugeot 207Ford Fiest...
# Diesel Hybrid                                                 BMW 3 Series
# Electric                 Mazda MX-30Nissan LeafNissan LeafNissan LeafNi...
# Petrol                   Vauxhall CorsaHyundai i30MINI HatchHyundai Cou...
# Petrol Hybrid            Honda CivicToyota PriusToyota CorollaHonda Fre...
# Petrol Plug-in Hybrid    BMW 3 SeriesBMW 3 SeriesBMW 3 SeriesBMW 3 Seri...
# Name: title, dtype: object

# %%
name = sns.countplot(x = 'Fuel type', data = car)
plt.grid(True)
plt.xticks(rotation='vertical', size=12)

plt.show()

# %%
car['Fuel type'].value_counts()
# Out:
# Fuel type
# Petrol                   2361
# Diesel                   1218
# Petrol Hybrid              47
# Electric                   31
# Petrol Plug-in Hybrid      27
# Diesel Hybrid               1
# Name: count, dtype: int64

# %%
car.head(5)
# Out:
#    id           title  Price  Mileage(miles)  Registration_Year  \
# 0   0     SKODA Fabia   6900           70189               2016
# 1   1  Vauxhall Corsa   1495           88585               2008
# 2   2     Hyundai i30    949          137000               2011
# 3   3      MINI Hatch   2395           96731               2010
# 4   4  Vauxhall Corsa   1000           85000               2013
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
# 2              0.0    Petrol  Hatchback   1.4L  Manual    5.0    5.0
# 3              5.0    Petrol  Hatchback   1.4L  Manual    3.0    4.0
# 4              0.0    Diesel  Hatchback   1.3L  Manual    5.0    5.0
#
#   Emission Class  Service history
# 0         Euro 6                0
# 1         Euro 4                1
# 2         Euro 5                0
# ...

# %%
car['Registration_Year'].value_counts()
# Out:
# Registration_Year
# 2011    289
# 2014    287
# 2012    275
# 2010    271
# 2009    251
# 2007    246
# 2016    245
# 2013    242
# 2008    226
# 2019    211
# 2015    210
# 2017    164
# 2006    149
# 2020    106
# 2005    104
# 2018     95
# 2021     85
# 2004     72
# 2003     53
# 2002     30
# 2001     25
# 2022      8
# 2023      6
# 1999      5
# 2000      4
# 1997      3
# 1990      3
# 1995      3
# 1998      3
# 1988      2
# 1987      2
# 1991      2
# 1972      1
# 1992      1
# 1996      1
# 1985      1
# 1981      1
# 1993      1
# 1989      1
# 1953      1
# Name: count, dtype: int64

# %%
car.groupby('Engine').title.sum()
# Out:
# Engine
# 0.0     BMW 3 SeriesToyota Mark XNissan CubicAudi A1Ma...
# 0.8L                          Chevrolet MatizSmart Fortwo
# 0.9L    Fiat 500CRenault ClioRenault CapturRenault Cap...
# 1.0L    Citroen C1Volkswagen PoloCitroen C1Ford FocusV...
# 1.1L    Fiat PandaMitsubishi ColtKIA PicantoMitsubishi...
# 1.2L    Vauxhall CorsaVauxhall CorsaVolkswagen PoloVol...
# 1.3L    Vauxhall CorsaMercedes-Benz A180Ford KAMercede...
# 1.4L    SKODA FabiaHyundai i30MINI HatchSKODA FabiaVau...
# 1.5L    Ford FocusMINI HatchMercedes-Benz B ClassRenau...
# 1.6L    Ford FocusPeugeot 207Ford FiestaPeugeot 207Cit...
# 1.7L    Vauxhall AstraMercedes-Benz B ClassVauxhall Me...
# 1.8L    Vauxhall InsigniaVauxhall AstraFord MondeoVaux...
# 1.9L    SKODA FabiaBMW 3 SeriesBMW 3 SeriesVolkswagen ...
# 2.0L    Hyundai CoupeBMW 3 SeriesSaab 9-3BMW 1 SeriesB...
# 2.1L    Mercedes-Benz C ClassMercedes-Benz C ClassMerc...
# 2.2L    Honda CivicVauxhall AntaraPeugeot 508Ford Mond...
# ...

# %%
car['Registration_Year'].value_counts()
# Out:
# Registration_Year
# 2011    289
# 2014    287
# 2012    275
# 2010    271
# 2009    251
# 2007    246
# 2016    245
# 2013    242
# 2008    226
# 2019    211
# 2015    210
# 2017    164
# 2006    149
# 2020    106
# 2005    104
# 2018     95
# 2021     85
# 2004     72
# 2003     53
# 2002     30
# 2001     25
# 2022      8
# 2023      6
# 1999      5
# 2000      4
# 1997      3
# 1990      3
# 1995      3
# 1998      3
# 1988      2
# 1987      2
# 1991      2
# 1972      1
# 1992      1
# 1996      1
# 1985      1
# 1981      1
# 1993      1
# 1989      1
# 1953      1
# Name: count, dtype: int64

# %%
car.head(2)
# Out:
#    id           title  Price  Mileage(miles)  Registration_Year  \
# 0   0     SKODA Fabia   6900           70189               2016
# 1   1  Vauxhall Corsa   1495           88585               2008
#
#    Previous Owners Fuel type  Body type Engine Gearbox  Doors  Seats  \
# 0              3.0    Diesel  Hatchback   1.4L  Manual    5.0    5.0
# 1              4.0    Petrol  Hatchback   1.2L  Manual    3.0    5.0
#
#   Emission Class  Service history
# 0         Euro 6                0
# 1         Euro 4                1

# %%
car.groupby('Registration_Year').get_group(2023)
# Out:
#         id           title  Price  Mileage(miles)  Registration_Year  \
# 2758  3587        MG MG HS  21495            1048               2023
# 2965  3851  Renault Arkana  21495           16228               2023
# 3098  4019        MG MG ZS  18365               1               2023
# 3100  4021      SEAT Ateca  25995             222               2023
# 3171  4107   Volkswagen UP   6750           55559               2023
# 3217  4173        MG MG ZS  18515               1               2023
#
#       Previous Owners Fuel type  Body type Engine    Gearbox  Doors  Seats  \
# 2758              1.0    Petrol        SUV   1.5L  Automatic    5.0    5.0
# 2965              1.0    Petrol        SUV   1.3L  Automatic    5.0    5.0
# 3098              0.0    Petrol        SUV   1.5L     Manual    5.0    5.0
# 3100              0.0    Petrol        SUV   1.5L     Manual    5.0    5.0
# 3171              0.0    Petrol  Hatchback   1.0L     Manual    5.0    4.0
# ...

# %% [markdown]
# #
#
# # Regards, Tariq Ibrahim
